# %%
import pandas as pd
import pyodbc 
con = pyodbc.connect("Driver={SQL Server};"
                      "Server=WILDEVDV02;"
                      "Trusted_Connection=TRUE;")

# %%
path = 'C:\\Users\\Cglan\\Documents\\projects\\outcomes-segmentation\\predict_out\\to_regress.csv'
data_in = pd.read_csv(path)
txtrack_ids = data_in.txtrack_id.unique
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-eef6f37a6999> in <module>()
#       1 path = 'C:\\Users\\Cglan\\Documents\\projects\\outcomes-segmentation\\predict_out\\to_regress.csv'
# ----> 2 data_in = pd.read_csv(path)
#       3 txtrack_ids = data_in.txtrack_id.unique
#
# NameError: name 'pd' is not defined

# %%
data = pd.read_sql(
    'SELECT name FROM sys.databases', con)
data
# Out:
#                   name
# 0               master
# 1               tempdb
# 2                model
# 3                 msdb
# 4         ReportServer
# 5   ReportServerTempDB
# 6          LoadingDock
# 7         WslWarehouse
# 8          WslTutorial
# 9              sandbox
# 10           DataVault
# 11       BusinessVault
# 12        BusinessMart
# 13     AvamereScrubbed
# 14        AvamereForms
# 15       ReferenceMart
# 16             AppData
# 17               Utils

# %%
data = pd.read_sql(
    "SELECT * FROM INFORMATION_SCHEMA.TABLES", con)
data
# Out:
#    TABLE_CATALOG TABLE_SCHEMA                                  TABLE_NAME  \
# 0   WslWarehouse          dbo                     v_patient_facility_stay
# 1   WslWarehouse          dim                           rox_SiteOfService
# 2   WslWarehouse          dim                              rox_ItemMaster
# 3   WslWarehouse          dim                                    rox_Date
# 4   WslWarehouse          dim                                 rox_JobRole
# 5   WslWarehouse          dim                         rox_PaidTimeOffType
# 6   WslWarehouse          dim                                   rox_Payer
# 7   WslWarehouse          dim                             rox_PayerAgency
# 8   WslWarehouse          dim                               rox_PayerType
# 9   WslWarehouse          dim                               rox_Physician
# 10  WslWarehouse          dim                           rox_PORExternalID
# 11  WslWarehouse          dim                                rox_RugScore
# 12  WslWarehouse          dim                        rox_ServiceIndicator
# 13  WslWarehouse          dim                        rox_AssessmentReason
# 14  WslWarehouse          dim                            rox_IntakeSource
# 15  WslWarehouse          dim                                rox_BillType
# 16  WslWarehouse          dim                             rox_LibraryItem
# 17  WslWarehouse          dim                      rox_CaseAndTrackStatus
# 18  WslWarehouse          dim                   rox_SiteOfServiceLocation
# 19  WslWarehouse          dim                                 rox_Company
# 20  WslWarehouse          dim                       rox_LibraryScaleValue
# 21  WslWarehouse          dim                                   rox_State
# 22  WslWarehouse          dim                            rox_AdmittedFrom
# 23  WslWarehouse          dim                                    rox_Time
# 24  WslWarehouse          dim                         rox_DischargeReason
# 25  WslWarehouse          dim                               rox_Diagnosis
# 26  WslWarehouse          dim                           rox_TypeOfTherapy
# 27  WslWarehouse          dim                      rox_DiagnosisIndicator
# 28  WslWarehouse          dim                       rox_LengthOfTreatment
# 29  WslWarehouse          dim                       rox_NonCareChargeItem
# 30  WslWarehouse          dim                             rox_DischargeTo
# 31  WslWarehouse          dim                              rox_Discipline
# 32  WslWarehouse          dim                              v_rox_Employee
# 33  WslWarehouse          dim                              v_rox_Resident
# 34  WslWarehouse          dim          rox_FunctionalAssessmentDefinition
# 35  WslWarehouse         fact            rox_EmployeeSiteOfServiceJobRole
# 36  WslWarehouse         fact                           rox_DirectBillTxn
# 37  WslWarehouse         fact                               rox_Encounter
# 38  WslWarehouse         fact                                   rox_Labor
# 39  WslWarehouse         fact                              rox_PriorUsage
# 40  WslWarehouse         fact                            rox_Productivity
# 41  WslWarehouse         fact                                 rox_Service
# 42  WslWarehouse         fact                          rox_TargetRugScore
# 43  WslWarehouse         fact                             rox_TrackDetail
# 44  WslWarehouse         fact                             rox_TxDiagnosis
# 45  WslWarehouse         fact  rox_FunctionalAssessmentMeasurementOutcome
#
#     TABLE_TYPE
# 0         VIEW
# 1   BASE TABLE
# 2   BASE TABLE
# 3   BASE TABLE
# 4   BASE TABLE
# 5   BASE TABLE
# 6   BASE TABLE
# 7   BASE TABLE
# 8   BASE TABLE
# 9   BASE TABLE
# 10  BASE TABLE
# 11  BASE TABLE
# 12  BASE TABLE
# 13  BASE TABLE
# 14  BASE TABLE
# 15  BASE TABLE
# 16  BASE TABLE
# 17  BASE TABLE
# 18  BASE TABLE
# 19  BASE TABLE
# 20  BASE TABLE
# 21  BASE TABLE
# 22  BASE TABLE
# 23  BASE TABLE
# 24  BASE TABLE
# 25  BASE TABLE
# 26  BASE TABLE
# 27  BASE TABLE
# 28  BASE TABLE
# 29  BASE TABLE
# 30  BASE TABLE
# 31  BASE TABLE
# 32        VIEW
# 33        VIEW
# 34  BASE TABLE
# 35  BASE TABLE
# 36  BASE TABLE
# 37  BASE TABLE
# 38  BASE TABLE
# 39  BASE TABLE
# 40  BASE TABLE
# 41  BASE TABLE
# 42  BASE TABLE
# 43  BASE TABLE
# 44  BASE TABLE
# 45  BASE TABLE

# %%
data = pd.read_sql(
    "SELECT top(10) * FROM WslWarehouse.fact.rox_FunctionalAssessmentMeasurementOutcome", con)
data
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# C:\Users\Cglan\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1400             else:
# -> 1401                 cur.execute(*args)
#    1402             return cur
#
# ProgrammingError: ('42S02', "[42S02] [Microsoft][ODBC SQL Server Driver][SQL Server]Invalid object name 'WslWarehouse.dim.v_Inf_ResidentOutcomes'. (208) (SQLExecDirectW)")
#
# During handling of the above exception, another exception occurred:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-8-2ee00cc6875b> in <module>()
#       1 data = pd.read_sql(
# ----> 2     "SELECT top(10) * FROM WslWarehouse.dim.v_Inf_ResidentOutcomes", con)
#       3 data
#
# C:\Users\Cglan\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\io\sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     397             sql, index_col=index_col, params=params,
#     398             coerce_float=coerce_float, parse_dates=parse_dates,
# --> 399             chunksize=chunksize)
#     400
#     401     try:
#
# C:\Users\Cglan\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1434
#    1435         args = _convert_params(sql, params)
# -> 1436         cursor = self.execute(*args)
#    1437         columns = [col_desc[0] for col_desc in cursor.description]
#    1438
#
# C:\Users\Cglan\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1411             ex = DatabaseError(
#    1412                 "Execution failed on sql '%s': %s" % (args[0], exc))
# -> 1413             raise_with_traceback(ex)
#    1414
#    1415     @staticmethod
#
# C:\Users\Cglan\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\compat\__init__.py in raise_with_traceback(exc, traceback)
#     338         if traceback == Ellipsis:
#     339             _, _, traceback = sys.exc_info()
# --> 340         raise exc.with_traceback(traceback)
#     341 else:
#     342     # this version of raise is a syntax error in Python 3
#
# C:\Users\Cglan\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1399                 cur.execute(*args, **kwargs)
#    1400             else:
# -> 1401                 cur.execute(*args)
#    1402             return cur
#    1403         except Exception as exc:
#
# DatabaseError: Execution failed on sql 'SELECT top(10) * FROM WslWarehouse.dim.v_Inf_ResidentOutcomes': ('42S02', "[42S02] [Microsoft][ODBC SQL Server Driver][SQL Server]Invalid object name 'WslWarehouse.dim.v_Inf_ResidentOutcomes'. (208) (SQLExecDirectW)")

# %%
qry = "SELECT COLUMN_NAME,* FROM INFORMATION_SCHEMA.COLUMNS WHERE TABLE_NAME = 'rox_FunctionalAssessmentMeasurementOutcome' AND TABLE_SCHEMA='fact' "
data = pd.read_sql(
   qry, con)
data
# Out:
#                                   COLUMN_NAME TABLE_CATALOG TABLE_SCHEMA  \
# 0   FunctionalAssessmentMeasurementOutcomeKey  WslWarehouse         fact
# 1                                  TxTrack_ID  WslWarehouse         fact
# 2                                 ResidentKey  WslWarehouse         fact
# 3                            SiteOfServiceKey  WslWarehouse         fact
# 4                           DiagnosisGroupKey  WslWarehouse         fact
# 5                              DischargeToKey  WslWarehouse         fact
# 6                          DischargeReasonKey  WslWarehouse         fact
# 7                        LengthOfTreatmentKey  WslWarehouse         fact
# 8                       EvalAssessmentDateKey  WslWarehouse         fact
# 9                  DischargeAssessmentDateKey  WslWarehouse         fact
# 10                              DisciplineKey  WslWarehouse         fact
# 11                               PhysicianKey  WslWarehouse         fact
# 12                                   PayerKey  WslWarehouse         fact
# 13                               PayerTypeKey  WslWarehouse         fact
# 14                            IntakeSourceKey  WslWarehouse         fact
# 15                            AdmittedFromKey  WslWarehouse         fact
# 16    PriorLivingLocationLibraryScaleValueKey  WslWarehouse         fact
# 17          FunctionalAssessmentDefinitionKey  WslWarehouse         fact
# 18                             LibraryItemKey  WslWarehouse         fact
# 19                   EvalLibraryScaleValueKey  WslWarehouse         fact
# 20                  DischLibraryScaleValueKey  WslWarehouse         fact
# 21                       EvalMeasurementValue  WslWarehouse         fact
# 22                  DischargeMeasurementValue  WslWarehouse         fact
# 23                         MeasurementOutcome  WslWarehouse         fact
# 24                            EvalDocument_ID  WslWarehouse         fact
# 25                            DischDocumentID  WslWarehouse         fact
# 26                               OutcomeCount  WslWarehouse         fact
# 27                 CreateAuditTableProcessKey  WslWarehouse         fact
# 28                 UpdateAuditTableProcessKey  WslWarehouse         fact
# 29                            dss_update_time  WslWarehouse         fact
#
#                                     TABLE_NAME  \
# 0   rox_FunctionalAssessmentMeasurementOutcome
# 1   rox_FunctionalAssessmentMeasurementOutcome
# 2   rox_FunctionalAssessmentMeasurementOutcome
# 3   rox_FunctionalAssessmentMeasurementOutcome
# 4   rox_FunctionalAssessmentMeasurementOutcome
# 5   rox_FunctionalAssessmentMeasurementOutcome
# 6   rox_FunctionalAssessmentMeasurementOutcome
# 7   rox_FunctionalAssessmentMeasurementOutcome
# 8   rox_FunctionalAssessmentMeasurementOutcome
# 9   rox_FunctionalAssessmentMeasurementOutcome
# 10  rox_FunctionalAssessmentMeasurementOutcome
# 11  rox_FunctionalAssessmentMeasurementOutcome
# 12  rox_FunctionalAssessmentMeasurementOutcome
# 13  rox_FunctionalAssessmentMeasurementOutcome
# 14  rox_FunctionalAssessmentMeasurementOutcome
# 15  rox_FunctionalAssessmentMeasurementOutcome
# 16  rox_FunctionalAssessmentMeasurementOutcome
# 17  rox_FunctionalAssessmentMeasurementOutcome
# 18  rox_FunctionalAssessmentMeasurementOutcome
# 19  rox_FunctionalAssessmentMeasurementOutcome
# 20  rox_FunctionalAssessmentMeasurementOutcome
# 21  rox_FunctionalAssessmentMeasurementOutcome
# 22  rox_FunctionalAssessmentMeasurementOutcome
# 23  rox_FunctionalAssessmentMeasurementOutcome
# 24  rox_FunctionalAssessmentMeasurementOutcome
# 25  rox_FunctionalAssessmentMeasurementOutcome
# 26  rox_FunctionalAssessmentMeasurementOutcome
# 27  rox_FunctionalAssessmentMeasurementOutcome
# 28  rox_FunctionalAssessmentMeasurementOutcome
# 29  rox_FunctionalAssessmentMeasurementOutcome
#
#                                   COLUMN_NAME  ORDINAL_POSITION  \
# 0   FunctionalAssessmentMeasurementOutcomeKey                 1
# 1                                  TxTrack_ID                 2
# 2                                 ResidentKey                 3
# 3                            SiteOfServiceKey                 4
# 4                           DiagnosisGroupKey                 5
# 5                              DischargeToKey                 6
# 6                          DischargeReasonKey                 7
# 7                        LengthOfTreatmentKey                 8
# 8                       EvalAssessmentDateKey                 9
# 9                  DischargeAssessmentDateKey                10
# 10                              DisciplineKey                11
# 11                               PhysicianKey                12
# 12                                   PayerKey                13
# 13                               PayerTypeKey                14
# 14                            IntakeSourceKey                15
# 15                            AdmittedFromKey                16
# 16    PriorLivingLocationLibraryScaleValueKey                17
# 17          FunctionalAssessmentDefinitionKey                18
# 18                             LibraryItemKey                19
# 19                   EvalLibraryScaleValueKey                20
# 20                  DischLibraryScaleValueKey                21
# 21                       EvalMeasurementValue                22
# 22                  DischargeMeasurementValue                23
# 23                         MeasurementOutcome                24
# 24                            EvalDocument_ID                25
# 25                            DischDocumentID                26
# 26                               OutcomeCount                27
# 27                 CreateAuditTableProcessKey                28
# 28                 UpdateAuditTableProcessKey                29
# 29                            dss_update_time                30
#
#    COLUMN_DEFAULT IS_NULLABLE DATA_TYPE CHARACTER_MAXIMUM_LENGTH     ...      \
# 0            None          NO    bigint                     None     ...
# 1            None         YES       int                     None     ...
# 2            None         YES       int                     None     ...
# 3            None         YES       int                     None     ...
# 4            None         YES       int                     None     ...
# 5            None         YES       int                     None     ...
# 6            None         YES       int                     None     ...
# 7            None         YES       int                     None     ...
# 8            None         YES       int                     None     ...
# 9            None         YES       int                     None     ...
# 10           None         YES       int                     None     ...
# 11           None         YES       int                     None     ...
# 12           None         YES       int                     None     ...
# 13           None         YES       int                     None     ...
# 14           None         YES       int                     None     ...
# 15           None         YES       int                     None     ...
# 16           None         YES       int                     None     ...
# 17           None         YES       int                     None     ...
# 18           None         YES       int                     None     ...
# 19           None         YES       int                     None     ...
# 20           None         YES       int                     None     ...
# 21           None         YES   numeric                     None     ...
# 22           None         YES   numeric                     None     ...
# 23           None         YES   numeric                     None     ...
# 24           None         YES       int                     None     ...
# 25           None         YES       int                     None     ...
# 26           None         YES       int                     None     ...
# 27           None         YES       int                     None     ...
# 28           None         YES       int                     None     ...
# 29           None         YES  datetime                     None     ...
#
#    DATETIME_PRECISION  CHARACTER_SET_CATALOG  CHARACTER_SET_SCHEMA  \
# 0                 NaN                   None                  None
# 1                 NaN                   None                  None
# 2                 NaN                   None                  None
# 3                 NaN                   None                  None
# 4                 NaN                   None                  None
# 5                 NaN                   None                  None
# 6                 NaN                   None                  None
# 7                 NaN                   None                  None
# 8                 NaN                   None                  None
# 9                 NaN                   None                  None
# 10                NaN                   None                  None
# 11                NaN                   None                  None
# 12                NaN                   None                  None
# 13                NaN                   None                  None
# 14                NaN                   None                  None
# 15                NaN                   None                  None
# 16                NaN                   None                  None
# 17                NaN                   None                  None
# 18                NaN                   None                  None
# 19                NaN                   None                  None
# 20                NaN                   None                  None
# 21                NaN                   None                  None
# 22                NaN                   None                  None
# 23                NaN                   None                  None
# 24                NaN                   None                  None
# 25                NaN                   None                  None
# 26                NaN                   None                  None
# 27                NaN                   None                  None
# 28                NaN                   None                  None
# 29                3.0                   None                  None
#
#     CHARACTER_SET_NAME  COLLATION_CATALOG COLLATION_SCHEMA COLLATION_NAME  \
# 0                 None               None             None           None
# 1                 None               None             None           None
# 2                 None               None             None           None
# 3                 None               None             None           None
# 4                 None               None             None           None
# 5                 None               None             None           None
# 6                 None               None             None           None
# 7                 None               None             None           None
# 8                 None               None             None           None
# 9                 None               None             None           None
# 10                None               None             None           None
# 11                None               None             None           None
# 12                None               None             None           None
# 13                None               None             None           None
# 14                None               None             None           None
# 15                None               None             None           None
# 16                None               None             None           None
# 17                None               None             None           None
# 18                None               None             None           None
# 19                None               None             None           None
# 20                None               None             None           None
# 21                None               None             None           None
# 22                None               None             None           None
# 23                None               None             None           None
# 24                None               None             None           None
# 25                None               None             None           None
# 26                None               None             None           None
# 27                None               None             None           None
# 28                None               None             None           None
# 29                None               None             None           None
#
#    DOMAIN_CATALOG DOMAIN_SCHEMA DOMAIN_NAME
# 0            None          None        None
# 1            None          None        None
# 2            None          None        None
# 3            None          None        None
# 4            None          None        None
# 5            None          None        None
# 6            None          None        None
# 7            None          None        None
# 8            None          None        None
# 9            None          None        None
# 10           None          None        None
# 11           None          None        None
# 12           None          None        None
# 13           None          None        None
# 14           None          None        None
# 15           None          None        None
# 16           None          None        None
# 17           None          None        None
# 18           None          None        None
# 19           None          None        None
# 20           None          None        None
# 21           None          None        None
# 22           None          None        None
# 23           None          None        None
# 24           None          None        None
# 25           None          None        None
# 26           None          None        None
# 27           None          None        None
# 28           None          None        None
# 29           None          None        None
#
# [30 rows x 24 columns]

# %%
qry = "SELECT\n
count(distinct(concat(TxTrack_ID, ResidentKey, PriorLivingLocationLibraryScaleValueKey))) FROM WslWarehouse.fact.rox_FunctionalAssessmentMeasurementOutcome"

data = pd.read_sql(
    qry, con)
data
# Out:
#
# 0  173289

# %%
# Out:
# <bound method Series.unique of 0        367857
# 1        368030
# 2        369244
# 3        369341
# 4        370304
# 5        371222
# 6        371290
# 7        371922
# 8        372182
# 9        372564
# 10       372593
# 11       372684
# 12       372891
# 13       374230
# 14       374473
# 15       375451
# 16       375527
# 17       375693
# 18       376809
# 19       376816
# 20       377119
# 21       377427
# 22       377606
# 23       377615
# 24       377679
# 25       377864
# 26       378042
# 27       378212
# 28       378436
# 29       378696
#           ...
# 32644    640879
# 32645    640892
# 32646    640901
# 32647    640986
# 32648    641082
# 32649    641098
# 32650    641150
# 32651    641208
# 32652    641213
# 32653    641217
# 32654    641218
# 32655    641226
# 32656    641231
# 32657    641234
# 32658    641240
# 32659    641261
# 32660    641393
# 32661    641481
# 32662    641552
# 32663    641593
# 32664    641607
# 32665    641647
# 32666    641687
# 32667    641982
# 32668    642064
# 32669    642107
# 32670    642175
# 32671    642184
# 32672    642231
# 32673    642426
# Name: txtrack_id, dtype: int64>

# %%
q = "SELECT TxTrack_ID, PriorLivingLocationLibraryScaleValueKey as PriorLiving, count(*) as Records FROM WslWarehouse.fact.rox_FunctionalAssessmentMeasurementOutcome"
q += " GROUP BY TxTrack_ID, PriorLivingLocationLibraryScaleValueKey"

data = pd.read_sql(
    q, con)

# %%
data_in.columns
# Out:
# Index(['txtrack_id', 'resident_id', 'facilityname', 'gender',
#        'payertypeabbrev', 'dischargetodescrip_3', 'dischargetodescrip_2',
#        'dischargetodescrip_4', 'tracklength', 'age',
#        'initialvalue_seconds_to_5x_sts_ordinal',
#        'initialvalue_seconds_to_walk_13_ft', 'initialvalue_six_min_walk',
#        'initialvalue_total_sppb', 'outcome_seconds_to_5x_sts_ordinal',
#        'outcome_seconds_to_walk_13_ft', 'outcome_six_min_walk',
#        'outcome_total_sppb', 'care_mob_sum_start', 'care_mob_sum_change'],
#       dtype='object')

# %%
data = data[['TxTrack_ID', 'PriorLiving']]
data
# Out:
#         TxTrack_ID  PriorLiving
# 0           487604         6133
# 1           383985           -1
# 2           439976         6133
# 3           589435         6130
# 4           564130         6127
# 5           587628         6130
# 6           391476         6130
# 7           399320         6129
# 8           515549         6130
# 9           614821         6127
# 10          455160         6131
# 11          598809         6133
# 12          604692         6133
# 13          409642         6133
# 14          457873         6130
# 15          559806         6129
# 16          452092         6133
# 17          560511         6129
# 18          625451         6130
# 19          517032         6134
# 20          411608         6131
# 21          405725         6131
# 22          623062         6126
# 23          504791         6132
# 24          529699         6134
# 25          399291         6131
# 26          436537         6126
# 27          488758         6130
# 28          546536         6133
# 29          482502         6131
# ...            ...          ...
# 173259      621260         6127
# 173260      505595         6130
# 173261      493111         6133
# 173262      495140         6126
# 173263      407558         6127
# 173264      466759         6133
# 173265      405571         6133
# 173266      436242         6133
# 173267      521278         6129
# 173268      463798         6130
# 173269      471937         6133
# 173270      582975         6130
# 173271      532420         6133
# 173272      452434         6133
# 173273      414974         6131
# 173274      465563         6131
# 173275      416230         6131
# 173276      403866         6130
# 173277      592412         6131
# 173278      592352         6133
# 173279      461991         6130
# 173280      484327         6129
# 173281      466819         6131
# 173282      473744         6133
# 173283      423019         6133
# 173284      444389         6131
# 173285      503710         6133
# 173286      591801         6133
# 173287      544413         6128
# 173288      618119         6130
#
# [173289 rows x 2 columns]

# %%
path = 'C:\\Users\\Cglan\\Documents\\projects\\outcomes-segmentation\\predict_out\\to_regress.csv'
data_in = pd.read_csv(path)
data_in = data_in.merge(data, left_on='txtrack_id', right_on= 'TxTrack_ID', how = 'left')
data_in
# Out:
#        txtrack_id  resident_id                           facilityname gender  \
# 0          367857       120972           Cashmere Convalescent Center      F
# 1          368030       121019         Avamere Hlth Svcs Rogue Valley      F
# 2          369244       121385                Linda Vista Care Center      M
# 3          369341       118259          Good Samaritan Spokane Valley      M
# 4          370304       116958                  Queen Anne Healthcare      F
# 5          371222       121587        Good Samaritan Society - Wymore      F
# 6          371290        27726           Porthaven Health Care Center      M
# 7          371922       122074      Good Samaritan Society - Beatrice      M
# 8          372182       122194  Prestige Care & Rehab - Pinewood Terr      M
# 9          372564       122319                Fairlawn Good Samaritan      M
# 10         372593       122209  Prestige PA & Rehab - Kittitas Valley      F
# 11         372684        90776              Prairie Manor Care Center      F
# 12         372891       122413           Cashmere Convalescent Center      M
# 13         374230       113334                            Marys Woods      F
# 14         374473        68006                Linda Vista Care Center      M
# 15         375451       123085                 Bethany at Silver Lake      F
# 16         375527       120176                  Richland Rehab Center      M
# 17         375693       123120                 Hood River Care Center      F
# 18         376809       123455                 Sante of Mesa-INACTIVE      M
# 19         376816       119742             Avamere Rehab of Beaverton      M
# 20         377119       123551      Prestige Care & Rehab - Sunnyside      M
# 21         377427       123691              West Hills Health & Rehab      F
# 22         377606        89223                Avamere Court at Keizer      F
# 23         377615       121774               Avamere at Pacific Ridge      M
# 24         377679       123653           Cashmere Convalescent Center      F
# 25         377864       123852             Avamere at Three Fountains      F
# 26         378042       123768           Porthaven Health Care Center      M
# 27         378212       123843     Prestige Care & Rehab - Menlo Park      F
# 28         378436       124007                 The Pearl at Kruse Way      F
# 29         378696       124054          Avamere Rehab of Cascade Park      M
# ...           ...          ...                                    ...    ...
# 32644      640879       198929           Bayview Retirement Community      M
# 32645      640892       198908      Prestige Care & Rehab of Reedwood      M
# 32646      640901       198902                        Cascade Terrace      F
# 32647      640986       198971        Prestige PA & Rehab - Milwaukie      M
# 32648      641082       188008      Prestige Care & Rehab - Clarkston      M
# 32649      641098       198894                 Rockwood South Hill OP      M
# 32650      641150       199040                Avamere TC of Sunnyside      M
# 32651      641208       199042          Good Samaritan Eugene Village      F
# 32652      641213       199043                Avamere Court at Keizer      F
# 32653      641217       198928    Idaho State Veterans Home-Pocatello      M
# 32654      641218       199022               Avamere Rehab of Newport      M
# 32655      641226       198993               Avamere Rehab of Newport      F
# 32656      641231       198532               Washington Care Services      M
# 32657      641234       198966                The Terraces at Skyline      U
# 32658      641240       178545          Laurelhurst Village Rehab Ctr      F
# 32659      641261       190450                 Bethany at Silver Lake      F
# 32660      641393       199111           Christian Health Care Center      F
# 32661      641481       161308                 Bend Transitional Care      F
# 32662      641552       199165               Puyallup Nursing & Rehab      F
# 32663      641593       199172               Copper Health Oro Valley      F
# 32664      641607       199152                     Village Healthcare      M
# 32665      641647       199090             Avamere Rehab of Hillsboro      F
# 32666      641687       198026                        Cascade Terrace      F
# 32667      641982       199215              Sunny Vista Living Center      F
# 32668      642064       175034          Prestige PA & Rehab - Edmonds      M
# 32669      642107       199309              Sunny Vista Living Center      F
# 32670      642175       199299                Creswell Health & Rehab      F
# 32671      642184        81204          Laurelhurst Village Rehab Ctr      F
# 32672      642231       199349           Avamere Rehab of Oregon City      F
# 32673      642426       199375             Shoreline Health and Rehab      F
#
#       payertypeabbrev dischargetodescrip_3  dischargetodescrip_2  \
# 0                 MCB       Long Term Care                     0
# 1                 MCD       Long Term Care                     0
# 2                 MCA         Not LTC/Home                     0
# 3                 MCA       Long Term Care                     0
# 4                 MCB       Long Term Care                     0
# 5                 MCB       Long Term Care                     0
# 6                 MCA         Not LTC/Home                     0
# 7                 MCA                 Home                     1
# 8                 MCA       Long Term Care                     0
# 9                 MCA                 Home                     1
# 10                MCD       Long Term Care                     0
# 11                MCA       Long Term Care                     0
# 12                MCA       Long Term Care                     0
# 13                MCB         Not LTC/Home                     0
# 14                 VA                 Home                     1
# 15                MCA         Not LTC/Home                     0
# 16                MCA                 Home                     1
# 17                MCA         Not LTC/Home                     0
# 18                MCA                 Home                     1
# 19                MGA         Not LTC/Home                     0
# 20                MCA                 Home                     1
# 21                MGA         Not LTC/Home                     0
# 22                MCA                 Home                     1
# 23                MGB       Long Term Care                     0
# 24                MCB       Long Term Care                     0
# 25                MCA                 Home                     1
# 26                MGA         Not LTC/Home                     0
# 27                MGA                 Home                     1
# 28                MGA                 Home                     1
# 29                MCA                 Home                     1
# ...               ...                  ...                   ...
# 32644             MCA                 Home                     1
# 32645             MGA         Not LTC/Home                     0
# 32646             MCA       Long Term Care                     0
# 32647             MGA         Not LTC/Home                     0
# 32648             MCB         Not LTC/Home                     0
# 32649             MCB         Not LTC/Home                     0
# 32650             MCA                 Home                     1
# 32651             MGA                 Home                     1
# 32652             MGA                 Home                     1
# 32653             MCB                 Home                     1
# 32654             MGA                 Home                     1
# 32655             MGA                 Home                     1
# 32656             MCA         Not LTC/Home                     0
# 32657             MCA                 Home                     1
# 32658             MCB         Not LTC/Home                     0
# 32659             MGA                 Home                     1
# 32660             MCA                 Home                     1
# 32661             MCA                 Home                     1
# 32662             MCA         Not LTC/Home                     0
# 32663             MGA                 Home                     1
# 32664             MGA                 Home                     1
# 32665             MGA         Not LTC/Home                     0
# 32666             MGA         Not LTC/Home                     0
# 32667             MGA                 Home                     1
# 32668             MGA                 Home                     1
# 32669             MGA                 Home                     1
# 32670             MCA         Not LTC/Home                     0
# 32671             MGB         Not LTC/Home                     0
# 32672             MCA                 Home                     1
# 32673             MCA         Not LTC/Home                     0
#
#        dischargetodescrip_4  tracklength  age     ...       \
# 0                         1           49   97     ...
# 1                         1           70   66     ...
# 2                         0           83   91     ...
# 3                         1           40   84     ...
# 4                         1           55   95     ...
# 5                         1           69   79     ...
# 6                         0           57   74     ...
# 7                         0           72   73     ...
# 8                         1           48   92     ...
# 9                         0           63   61     ...
# 10                        1           59   34     ...
# 11                        1           98   74     ...
# 12                        1           71   83     ...
# 13                        0           55   91     ...
# 14                        0           49   88     ...
# 15                        0           19   81     ...
# 16                        0           44   81     ...
# 17                        0           63   87     ...
# 18                        0           39   82     ...
# 19                        0           37   87     ...
# 20                        0           37   74     ...
# 21                        0           58   98     ...
# 22                        0           34   75     ...
# 23                        1           35   75     ...
# 24                        1           54   92     ...
# 25                        0           32   68     ...
# 26                        0           88   33     ...
# 27                        0           55   53     ...
# 28                        0           26   79     ...
# 29                        0           31   91     ...
# ...                     ...          ...  ...     ...
# 32644                     0            5   72     ...
# 32645                     0            6   52     ...
# 32646                     1            2   96     ...
# 32647                     0           10   81     ...
# 32648                     0            6   83     ...
# 32649                     0            5   86     ...
# 32650                     0            7   52     ...
# 32651                     0            8   74     ...
# 32652                     0            7   73     ...
# 32653                     0            7   68     ...
# 32654                     0            6   66     ...
# 32655                     0            6   67     ...
# 32656                     0            1   72     ...
# 32657                     0            9   80     ...
# 32658                     0            5   67     ...
# 32659                     0            8   78     ...
# 32660                     0            7   72     ...
# 32661                     0            6   73     ...
# 32662                     0            5   92     ...
# 32663                     0            3   54     ...
# 32664                     0            3   65     ...
# 32665                     0            0   22     ...
# 32666                     0            6   65     ...
# 32667                     0            4   89     ...
# 32668                     0            3   74     ...
# 32669                     0            4   78     ...
# 32670                     0            1   84     ...
# 32671                     0            0   82     ...
# 32672                     0            4   83     ...
# 32673                     0            0   83     ...
#
#        initialvalue_six_min_walk  initialvalue_total_sppb  \
# 0                             10                        1
# 1                             34                        2
# 2                            280                        2
# 3                            642                        3
# 4                            400                        2
# 5                            300                        3
# 6                            100                        3
# 7                            128                        1
# 8                            318                        5
# 9                              0                        0
# 10                            96                        5
# 11                           285                        2
# 12                            50                        3
# 13                           900                        8
# 14                           150                        3
# 15                            34                        2
# 16                             1                        1
# 17                           100                        1
# 18                            20                        0
# 19                           395                        5
# 20                           200                        5
# 21                             0                        1
# 22                           175                        1
# 23                           180                        1
# 24                           210                        6
# 25                           121                        1
# 26                             0                        0
# 27                            65                        0
# 28                           400                        3
# 29                           315                        1
# ...                          ...                      ...
# 32644                        659                       10
# 32645                         98                        3
# 32646                          0                        0
# 32647                          0                        0
# 32648                          4                        1
# 32649                          0                        0
# 32650                       1014                        9
# 32651                        227                        6
# 32652                         50                        2
# 32653                         70                        5
# 32654                        700                        6
# 32655                        150                        7
# 32656                         40                        3
# 32657                        760                        8
# 32658                          0                        0
# 32659                        180                        1
# 32660                        125                        1
# 32661                        396                        6
# 32662                          0                        0
# 32663                        132                        3
# 32664                        405                        1
# 32665                          0                        0
# 32666                        590                        4
# 32667                          5                        0
# 32668                          0                        0
# 32669                          3                        0
# 32670                          0                        0
# 32671                        410                        4
# 32672                        217                        5
# 32673                          0                        0
#
#        outcome_seconds_to_5x_sts_ordinal  outcome_seconds_to_walk_13_ft  \
# 0                                      0                         0.0000
# 1                                      0                         0.7046
# 2                                      3                         0.9975
# 3                                      0                         2.2988
# 4                                      1                         1.3025
# 5                                      1                         1.2287
# 6                                      0                         0.9311
# 7                                      0                         0.9721
# 8                                      3                        -0.1988
# 9                                      1                         2.1867
# 10                                     3                         0.3861
# 11                                     3                         1.4516
# 12                                     0                         2.1462
# 13                                    -2                        -0.6431
# 14                                     3                         0.9940
# 15                                     0                        -0.0007
# 16                                     2                         1.5712
# 17                                     4                         1.7043
# 18                                     0                         0.0000
# 19                                    -1                         0.2789
# 20                                     3                         1.0168
# 21                                     0                         1.1439
# 22                                     0                        -0.1730
# 23                                     0                         0.4548
# 24                                     3                         0.1146
# 25                                     1                         0.8902
# 26                                     0                         1.1281
# 27                                     2                         1.9680
# 28                                     3                         0.9705
# 29                                     2                         2.0364
# ...                                  ...                            ...
# 32644                                  1                         1.4644
# 32645                                  0                         0.1692
# 32646                                  0                         0.0000
# 32647                                  0                         0.8547
# 32648                                  0                         1.0000
# 32649                                  0                         0.0000
# 32650                                 -1                         0.7680
# 32651                                  2                         2.0536
# 32652                                  0                         0.8883
# 32653                                  0                         1.4609
# 32654                                  1                         0.6811
# 32655                                  0                        -0.0095
# 32656                                  0                         0.0000
# 32657                                  2                         0.4037
# 32658                                  0                         0.0000
# 32659                                  0                         0.6366
# 32660                                  0                         3.0084
# 32661                                 -2                        -0.6906
# 32662                                  3                         2.4478
# 32663                                  2                         0.7655
# 32664                                  0                         0.8775
# 32665                                  0                         0.0000
# 32666                                  0                         0.5466
# 32667                                  0                         2.5231
# 32668                                  0                         0.0000
# 32669                                  0                         0.0000
# 32670                                  0                         0.0000
# 32671                                  0                         0.0000
# 32672                                  1                         0.4187
# 32673                                  0                         0.0000
#
#        outcome_six_min_walk  outcome_total_sppb  care_mob_sum_start  \
# 0                         0                   0                  19
# 1                        91                   1                  19
# 2                       530                   7                  30
# 3                       707                   5                  14
# 4                       546                   7                  42
# 5                       250                   4                  27
# 6                       220                   4                  23
# 7                       222                   4                  25
# 8                       257                   3                  33
# 9                       420                   6                  14
# 10                      624                   5                  48
# 11                      655                   6                  97
# 12                      159                   3                  21
# 13                      190                  -2                  43
# 14                      671                   6                  40
# 15                       49                   1                  29
# 16                      172                   5                  37
# 17                      410                   9                  45
# 18                       76                   1                  26
# 19                     -177                   0                  29
# 20                      650                   4                  30
# 21                      970                   2                  24
# 22                       50                   0                  23
# 23                      -30                   1                  29
# 24                      579                   3                  29
# 25                      569                   2                  22
# 26                       50                   3                  38
# 27                      946                   7                  20
# 28                      280                   7                  26
# 29                      145                   8                  23
# ...                     ...                 ...                 ...
# 32644                   131                   2                  74
# 32645                     2                   0                  63
# 32646                     0                   0                  15
# 32647                   579                   2                  31
# 32648                   196                   1                  43
# 32649                     0                   0                  11
# 32650                   386                  -1                  64
# 32651                   746                   4                  48
# 32652                    85                   4                  44
# 32653                   690                   2                  49
# 32654                   550                   4                  58
# 32655                    50                   0                  78
# 32656                     0                   0                  36
# 32657                   292                   3                  65
# 32658                     0                   0                  27
# 32659                   130                   4                  42
# 32660                   825                   4                  47
# 32661                  -137                  -3                  80
# 32662                   750                   9                  34
# 32663                   306                   4                  43
# 32664                    65                   3                  54
# 32665                     0                   0                  34
# 32666                   154                   2                  46
# 32667                   295                   5                  29
# 32668                     0                   0                  17
# 32669                     7                   3                  29
# 32670                     0                   0                  17
# 32671                     0                   0                  50
# 32672                   354                   2                  44
# 32673                     0                   0                  26
#
#        care_mob_sum_change  TxTrack_ID  PriorLiving
# 0                        0    367857.0         -1.0
# 1                       11    368030.0         -1.0
# 2                       24    369244.0         -1.0
# 3                        4    369341.0         -1.0
# 4                        0    370304.0         -1.0
# 5                        3    371222.0         -1.0
# 6                        7    371290.0         -1.0
# 7                       -3    371922.0         -1.0
# 8                       21    372182.0         -1.0
# 9                       36    372564.0         -1.0
# 10                      12    372593.0         -1.0
# 11                       1    372684.0         -1.0
# 12                      12    372891.0         -1.0
# 13                       1    374230.0         -1.0
# 14                       6    374473.0         -1.0
# 15                       8    375451.0         -1.0
# 16                     -12    375527.0         -1.0
# 17                      -3    375693.0         -1.0
# 18                      10    376809.0         -1.0
# 19                      13    376816.0         -1.0
# 20                      24    377119.0         -1.0
# 21                      35    377427.0         -1.0
# 22                       4    377606.0         -1.0
# 23                      17    377615.0         -1.0
# 24                      14    377679.0         -1.0
# 25                      19    377864.0         -1.0
# 26                      53    378042.0         -1.0
# 27                      26    378212.0         -1.0
# 28                       7    378436.0         -1.0
# 29                      -1    378696.0         -1.0
# ...                    ...         ...          ...
# 32644                   10         NaN          NaN
# 32645                   17         NaN          NaN
# 32646                    3         NaN          NaN
# 32647                   32         NaN          NaN
# 32648                    5         NaN          NaN
# 32649                    0         NaN          NaN
# 32650                    4         NaN          NaN
# 32651                   36         NaN          NaN
# 32652                   26         NaN          NaN
# 32653                   17         NaN          NaN
# 32654                   20         NaN          NaN
# 32655                   -6         NaN          NaN
# 32656                  -16         NaN          NaN
# 32657                   17         NaN          NaN
# 32658                    0         NaN          NaN
# 32659                   29         NaN          NaN
# 32660                   30         NaN          NaN
# 32661                  -15         NaN          NaN
# 32662                   28         NaN          NaN
# 32663                   33         NaN          NaN
# 32664                   23         NaN          NaN
# 32665                    0         NaN          NaN
# 32666                   18         NaN          NaN
# 32667                   43         NaN          NaN
# 32668                   14         NaN          NaN
# 32669                   18         NaN          NaN
# 32670                    0         NaN          NaN
# 32671                    4         NaN          NaN
# 32672                   10         NaN          NaN
# 32673                    5         NaN          NaN
#
# [32674 rows x 22 columns]

# %%
data_in.to_csv('C:\\Users\\Cglan\\Documents\\projects\\outcomes-segmentation\\predict_out\\to_regress_w_prior_living.csv')

# %%
q = "SELECT TOP(10) * FROM WslWarehouse.dim.v_rox_Resident"

data = pd.read_sql(
    q, con)
data
# Out:
#    rox_Resident_key  ResidentKey  Resident_ID MaritalStatus  \
# 0                 0          NaN          NaN       Unknown
# 1                 1         -2.0         -2.0           N/A
# 2                 2         -1.0         -1.0       Unknown
# 3                 3          1.0          1.0       Unknown
# 4                 4          2.0          2.0       Unknown
# 5                 5          3.0          3.0       Unknown
# 6                 6          4.0          4.0       Unknown
# 7                 7          5.0          5.0       Unknown
# 8                 8          6.0          6.0       Unknown
# 9                 9          7.0          8.0       Unknown
#
#   IsUnitedStatesCitizen CitizenshipCountry MedicareNumber MedicaidNumber  \
# 0                  None            Unknown        Unknown        Unknown
# 1                 False                N/A            N/A            N/A
# 2                 False            Unknown        Unknown        Unknown
# 3                 False            Unknown        Unknown        Unknown
# 4                 False            Unknown        Unknown        Unknown
# 5                 False            Unknown        Unknown        Unknown
# 6                 False            Unknown        Unknown        Unknown
# 7                 False            Unknown        Unknown        Unknown
# 8                 False            Unknown        Unknown        Unknown
# 9                 False            Unknown        Unknown        Unknown
#
#   MedicaidCode MedicareEligibility MedicaidEligibility EntitlementDateMCA  \
# 0      Unknown             Unknown             Unknown                NaT
# 1          N/A                 N/A                 N/A         1900-01-01
# 2      Unknown             Unknown             Unknown         1900-01-01
# 3      Unknown             Unknown             Unknown         1900-01-01
# 4      Unknown             Unknown             Unknown         1900-01-01
# 5      Unknown             Unknown             Unknown         1900-01-01
# 6      Unknown             Unknown             Unknown         1900-01-01
# 7      Unknown             Unknown             Unknown         1900-01-01
# 8      Unknown             Unknown             Unknown         1900-01-01
# 9      Unknown             Unknown             Unknown         1900-01-01
#
#   EntitlementDateMCB EntitlementDateMCD IsMilitaryService MilitaryBranch  \
# 0                NaT                NaT              None        Unknown
# 1         1900-01-01         1900-01-01             False            N/A
# 2         1900-01-01         1900-01-01             False        Unknown
# 3         1900-01-01         1900-01-01             False        Unknown
# 4         1900-01-01         1900-01-01             False        Unknown
# 5         1900-01-01         1900-01-01             False        Unknown
# 6         1900-01-01         1900-01-01             False        Unknown
# 7         1900-01-01         1900-01-01             False        Unknown
# 8         1900-01-01         1900-01-01             False        Unknown
# 9         1900-01-01         1900-01-01             False        Unknown
#
#   ADTPatientIdentifier ADTPatientNumber IsDeleted         dss_update_time
# 0              Unknown          Unknown      None 2017-02-08 09:26:37.207
# 1              Unknown          Unknown     False 2017-02-08 09:26:37.207
# 2              Unknown          Unknown     False 2017-02-08 09:26:37.207
# 3              Unknown          Unknown     False 2017-02-08 09:26:37.207
# 4              Unknown          Unknown     False 2017-02-08 09:26:37.207
# 5              Unknown          Unknown     False 2017-02-08 09:26:37.207
# 6              Unknown          Unknown     False 2017-02-08 09:26:37.207
# 7              Unknown          Unknown     False 2017-02-08 09:26:37.207
# 8              Unknown          Unknown     False 2017-02-08 09:26:37.207
# 9              Unknown          Unknown     False 2017-02-08 09:26:37.207
