# %%
import pandas as pd
import pyodbc 
con = pyodbc.connect("Driver={SQL Server};"
                      "Server=WILDEVDV02;"
                      "Trusted_Connection=TRUE;")

sql = 'SELECT TOP(10) * FROM sys.objects'
data = pd.read_sql(sql, con)
data
# Out:
#                         name  object_id principal_id  schema_id  \
# 0  rox_PaidTimeOffType_idx_0     719055         None          6
# 1            rox_PayerAgency   80719340         None          6
# 2      rox_PayerAgency_idx_0  128719511         None          6
# 3              rox_PayerType  144719568         None          6
# 4        rox_PayerType_idx_0  192719739         None          6
# 5              rox_Physician  208719796         None          6
# 6        rox_Physician_idx_0  256719967         None          6
# 7          rox_PORExternalID  272720024         None          6
# 8    rox_PORExternalID_idx_0  320720195         None          6
# 9               rox_RugScore  400720480         None          6
#
#    parent_object_id type               type_desc             create_date  \
# 0        2100202532   PK  PRIMARY_KEY_CONSTRAINT 2017-02-08 09:17:26.350
# 1                 0   U               USER_TABLE 2017-02-08 09:20:18.247
# ...
